# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#A-little-data-cleaning" data-toc-modified-id="A-little-data-cleaning-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>A little data cleaning</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Missing-Data" data-toc-modified-id="Missing-Data-1.0.1"><span class="toc-item-num">1.0.1&nbsp;&nbsp;</span>Missing Data</a></span></li><li><span><a href="#Describe-Child-Poverty-to-use-in-deciding-how-to-impute" data-toc-modified-id="Describe-Child-Poverty-to-use-in-deciding-how-to-impute-1.0.2"><span class="toc-item-num">1.0.2&nbsp;&nbsp;</span>Describe Child Poverty to use in deciding how to impute</a></span></li><li><span><a href="#Looking-for-duplicates" data-toc-modified-id="Looking-for-duplicates-1.0.3"><span class="toc-item-num">1.0.3&nbsp;&nbsp;</span>Looking for duplicates</a></span></li><li><span><a href="#Changing-the-data-type" data-toc-modified-id="Changing-the-data-type-1.0.4"><span class="toc-item-num">1.0.4&nbsp;&nbsp;</span>Changing the data type</a></span></li><li><span><a href="#Remove-a-single-column" data-toc-modified-id="Remove-a-single-column-1.0.5"><span class="toc-item-num">1.0.5&nbsp;&nbsp;</span>Remove a single column</a></span></li><li><span><a href="#Remove-multiple-columns" data-toc-modified-id="Remove-multiple-columns-1.0.6"><span class="toc-item-num">1.0.6&nbsp;&nbsp;</span>Remove multiple columns</a></span></li></ul></li></ul></li><li><span><a href="#Exploratory-Data-Analysis" data-toc-modified-id="Exploratory-Data-Analysis-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Exploratory Data Analysis</a></span><ul class="toc-item"><li><span><a href="#Examine-Diabetes-column" data-toc-modified-id="Examine-Diabetes-column-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Examine Diabetes column</a></span><ul class="toc-item"><li><span><a href="#Histograms" data-toc-modified-id="Histograms-2.1.1"><span class="toc-item-num">2.1.1&nbsp;&nbsp;</span>Histograms</a></span></li><li><span><a href="#Boxplots" data-toc-modified-id="Boxplots-2.1.2"><span class="toc-item-num">2.1.2&nbsp;&nbsp;</span>Boxplots</a></span></li><li><span><a href="#Violinplots" data-toc-modified-id="Violinplots-2.1.3"><span class="toc-item-num">2.1.3&nbsp;&nbsp;</span>Violinplots</a></span></li><li><span><a href="#Counting-unique-values-for-each-variable" data-toc-modified-id="Counting-unique-values-for-each-variable-2.1.4"><span class="toc-item-num">2.1.4&nbsp;&nbsp;</span>Counting unique values for each variable</a></span></li></ul></li></ul></li><li><span><a href="#" data-toc-modified-id="-3"><span class="toc-item-num">3&nbsp;&nbsp;</span></a></span><ul class="toc-item"><li><span><a href="#Bar-Charts" data-toc-modified-id="Bar-Charts-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Bar Charts</a></span><ul class="toc-item"><li><span><a href="#Count-number-of-rows-for-each-unique-value-of-a-variable" data-toc-modified-id="Count-number-of-rows-for-each-unique-value-of-a-variable-3.1.1"><span class="toc-item-num">3.1.1&nbsp;&nbsp;</span>Count number of rows for each unique value of a variable</a></span></li><li><span><a href="#Multiple-bar-charts-in-a-figure" data-toc-modified-id="Multiple-bar-charts-in-a-figure-3.1.2"><span class="toc-item-num">3.1.2&nbsp;&nbsp;</span>Multiple bar charts in a figure</a></span></li><li><span><a href="#Binning-numeric-values-into-groups" data-toc-modified-id="Binning-numeric-values-into-groups-3.1.3"><span class="toc-item-num">3.1.3&nbsp;&nbsp;</span>Binning numeric values into groups</a></span></li></ul></li></ul></li><li><span><a href="#Scatterplots" data-toc-modified-id="Scatterplots-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Scatterplots</a></span></li><li><span><a href="#Linear-regressions" data-toc-modified-id="Linear-regressions-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Linear regressions</a></span></li></ul></div>

# %%
# DO NOT CHANGE

import numpy as np
import pandas as pd
import seaborn as sns
import statsmodels.api as sm
import matplotlib.pyplot as plt
# %matplotlib inline
# from scipy.stats import pearsonr
import scipy.stats as stats 
#from sklearn import preprocessing

plt.figure(figsize=(20, 20))

# %%
# DO NOT CHANGE

df = pd.read_csv('https://raw.githubusercontent.com/jimcody2014/Python-Data/main/DAClass/Outcomes-Final.csv')

# %%
df.shape     # Rows and columns in the dataset
# Out:
# (584, 53)

# %%
df.head()    # Show the first five rows
# Out:
#   StateAbbr     State    County  CountyFIPS  ARTHRITIS  CASTHMA  BPHIGH  \
# 0        AR  Arkansas  Arkansas        5001       35.5     10.7    44.2
# 1        AR  Arkansas    Ashley        5003       36.1     10.7    44.8
# 2        AR  Arkansas    Baxter        5005       39.4      9.6    44.0
# 3        AR  Arkansas    Benton        5007       25.8      9.0    30.7
# 4        AR  Arkansas     Boone        5009       35.7      9.9    39.9
#
#    CANCER  HIGHCHOL  KIDNEY  ...  MeanCommute  MeanHealthCommute  Employed  \
# 0     8.1      39.4     3.9  ...         14.6              30.25      7920
# 1     8.2      39.1     4.1  ...         20.4              40.27      7905
# 2    10.4      42.6     4.0  ...         16.4              30.43     15926
# 3     6.9      32.4     2.6  ...         19.9              48.63    119813
# 4     8.6      38.8     3.5  ...         19.4              39.22     15773
#
#    PrivateWork  PublicWork  SelfEmployed  FamilyWork  Unemployment%_2019  \
# 0         75.7        15.5           8.0         0.9                 3.0
# 1         78.8        18.1           2.7         0.4                 5.4
# 2         79.5        11.7           8.6         0.2                 4.0
# 3         86.0         8.2           5.7         0.1                 2.6
# 4         78.4        13.1           8.2         0.3                 3.2
#
#   Median Household Income_2019  % of State Median HH Income
# 0                        52539                     1.071787
# 1                        47744                     0.973970
# 2                        41950                     0.855773
# 3                        70775                     1.443798
# 4                        50083                     1.021685
#
# [5 rows x 53 columns]

# %%
df.tail()    # Show the last five rows
# Out:
#     StateAbbr  State  County  CountyFIPS  ARTHRITIS  CASTHMA  BPHIGH  CANCER  \
# 579        TX  Texas    Wood       48499       33.7      9.5    41.8     9.3
# 580        TX  Texas  Yoakum       48501       22.5      8.5    33.3     5.9
# 581        TX  Texas   Young       48503       31.0      9.4    39.3     8.2
# 582        TX  Texas  Zapata       48505       24.9      9.3    36.6     5.4
# 583        TX  Texas  Zavala       48507       24.9      9.2    38.5     5.3
#
#      HIGHCHOL  KIDNEY  ...  MeanCommute  MeanHealthCommute  Employed  \
# 579      41.7     4.0  ...         30.2              57.05     15960
# 580      35.5     3.1  ...         16.2              32.04      3755
# 581      39.2     3.6  ...         15.3              27.88      8248
# 582      37.1     4.6  ...         18.2              28.45      5146
# 583      38.6     4.7  ...         13.7              20.66      4397
#
#      PrivateWork  PublicWork  SelfEmployed  FamilyWork  Unemployment%_2019  \
# 579         78.4        14.1           7.1         NaN                 3.9
# 580         71.7        17.5          10.7         NaN                 2.9
# 581         69.8        17.1          11.9         NaN                 3.0
# 582         66.0        21.0          12.6         NaN                 5.1
# 583         73.9        21.2           4.9         NaN                 8.5
#
#     Median Household Income_2019  % of State Median HH Income
# 579                        56945                     0.889154
# 580                        62636                     0.978015
# 581                        52643                     0.821982
# 582                        36069                     0.563191
# 583                        32538                     0.508057
#
# [5 rows x 53 columns]

# %%
df.info()    # How python views the data types
             # If the number next to the variable name does not equal the number of rows in the shape
             # it means there is missing data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 584 entries, 0 to 583
# Data columns (total 53 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   StateAbbr                     584 non-null    object
#  1   State                         584 non-null    object
#  2   County                        584 non-null    object
#  3   CountyFIPS                    584 non-null    int64
#  4   ARTHRITIS                     584 non-null    float64
#  5   CASTHMA                       584 non-null    float64
#  6   BPHIGH                        584 non-null    float64
#  7   CANCER                        584 non-null    float64
#  8   HIGHCHOL                      584 non-null    float64
#  9   KIDNEY                        584 non-null    float64
#  10  COPD                          584 non-null    float64
#  11  CHD                           584 non-null    float64
#  12  DIABETES                      584 non-null    float64
#  13  MHLTH                         584 non-null    float64
#  14  PHLTH                         584 non-null    float64
#  15  TEETHLOST                     584 non-null    float64
#  16  STROKE                        584 non-null    float64
#  17  TotalPopulation               584 non-null    int64
#  18  GenderMajority                584 non-null    object
#  19  Men                           584 non-null    int64
#  20  Women                         584 non-null    int64
#  21  Hispanic                      584 non-null    float64
#  22  White                         584 non-null    float64
#  23  Black                         584 non-null    float64
#  24  Native                        584 non-null    float64
#  25  Asian                         584 non-null    float64
#  26  Pacific                       584 non-null    float64
#  27  VotingAgeCitizen              584 non-null    int64
#  28  Income                        584 non-null    int64
#  29  IncomePerCap                  584 non-null    int64
#  30  IncomePerCapErr               584 non-null    int64
#  31  ChildPoverty                  575 non-null    float64
#  32  Professional                  584 non-null    float64
#  33  Service                       584 non-null    float64
#  34  Office                        584 non-null    float64
#  35  Construction                  584 non-null    float64
#  36  Production                    584 non-null    float64
#  37  Drive                         584 non-null    float64
#  38  Carpool                       584 non-null    float64
#  39  Transit                       584 non-null    float64
#  40  Walk                          584 non-null    float64
#  41  OtherTransp                   584 non-null    float64
#  42  WorkAtHome                    584 non-null    float64
#  43  MeanCommute                   584 non-null    float64
#  44  MeanHealthCommute             584 non-null    float64
#  45  Employed                      584 non-null    int64
#  46  PrivateWork                   584 non-null    float64
#  47  PublicWork                    584 non-null    float64
#  48  SelfEmployed                  584 non-null    float64
#  49  FamilyWork                    303 non-null    float64
#  50  Unemployment%_2019            584 non-null    float64
#  51  Median Household Income_2019  584 non-null    int64
#  52  % of State Median HH Income   584 non-null    float64
# dtypes: float64(39), int64(10), object(4)
# memory usage: 241.9+ KB

# %%
df.describe()
# Out:
#          CountyFIPS   ARTHRITIS     CASTHMA      BPHIGH      CANCER  \
# count    584.000000  584.000000  584.000000  584.000000  584.000000
# mean   32965.486301   30.338356    9.810959   39.155137    7.455137
# std    18487.838974    5.270823    0.874932    4.630291    1.182770
# min     5001.000000   13.900000    7.800000   20.400000    3.100000
# 25%    13144.500000   26.400000    9.200000   36.075000    6.700000
# 50%    47116.000000   30.300000    9.800000   39.400000    7.500000
# 75%    48215.500000   34.225000   10.500000   42.300000    8.300000
# max    48507.000000   42.400000   12.000000   52.300000   11.000000
#
#          HIGHCHOL      KIDNEY        COPD         CHD    DIABETES  ...  \
# count  584.000000  584.000000  584.000000  584.000000  584.000000  ...
# mean    37.896404    3.654623    9.611130    9.085445   14.673288  ...
# std      3.254922    0.576955    2.133542    1.732173    2.456476  ...
# min     21.200000    1.800000    4.500000    3.500000    6.700000  ...
# 25%     35.900000    3.300000    8.100000    7.900000   13.200000  ...
# 50%     38.100000    3.600000    9.600000    9.200000   14.600000  ...
# 75%     40.100000    4.000000   11.100000   10.200000   16.000000  ...
# max     45.200000    5.900000   15.500000   13.500000   23.900000  ...
#
#        MeanCommute  MeanHealthCommute      Employed  PrivateWork  PublicWork  \
# count   584.000000         584.000000  5.840000e+02   584.000000  584.000000
# mean     24.338527          45.445240  3.696515e+04    74.525685   17.441610
# std       5.267917          12.422819  1.325775e+05     5.995441    5.153703
# min       7.700000          14.020000  3.900000e+01    50.400000    7.500000
# 25%      20.400000          36.977500  3.948250e+03    71.700000   13.800000
# 50%      23.900000          43.015000  8.365000e+03    75.400000   16.400000
# 75%      28.025000          52.585000  2.096900e+04    78.725000   20.025000
# max      41.300000          92.520000  2.180392e+06    86.400000   39.500000
#
#        SelfEmployed  FamilyWork  Unemployment%_2019  \
# count    584.000000  303.000000          584.000000
# mean       7.807877    0.181188            3.782363
# std        3.041047    0.234470            1.011977
# min        0.000000    0.000000            0.700000
# 25%        5.700000    0.000000            3.100000
# 50%        7.100000    0.100000            3.600000
# 75%        9.200000    0.200000            4.300000
# max       21.800000    1.400000            9.800000
#
#        Median Household Income_2019  % of State Median HH Income
# count                    584.000000                   584.000000
# mean                   51448.924658                     0.855764
# std                    13177.786949                     0.209338
# min                    24732.000000                     0.399225
# 25%                    42504.500000                     0.712665
# 50%                    48260.500000                     0.820428
# 75%                    57167.000000                     0.946734
# max                   119637.000000                     2.134583
#
# [8 rows x 49 columns]

# %% [markdown]
# # A little data cleaning
#
# 1. Check for missing values
# 2. Check for duplicate data
# 3. Change column type
# 4. Remove data that will not add value (e.g., car id)

# %% [markdown]
# ### Missing Data

# %%
# Just listing the columns and how many rows 
# for each have a missing value.

df.isnull().sum()
# Out:
# StateAbbr                         0
# State                             0
# County                            0
# CountyFIPS                        0
# ARTHRITIS                         0
# CASTHMA                           0
# BPHIGH                            0
# CANCER                            0
# HIGHCHOL                          0
# KIDNEY                            0
# COPD                              0
# CHD                               0
# DIABETES                          0
# MHLTH                             0
# PHLTH                             0
# TEETHLOST                         0
# STROKE                            0
# TotalPopulation                   0
# GenderMajority                    0
# Men                               0
# Women                             0
# Hispanic                          0
# White                             0
# Black                             0
# Native                            0
# Asian                             0
# Pacific                           0
# VotingAgeCitizen                  0
# Income                            0
# IncomePerCap                      0
# IncomePerCapErr                   0
# ChildPoverty                      9
# Professional                      0
# Service                           0
# Office                            0
# Construction                      0
# Production                        0
# Drive                             0
# Carpool                           0
# Transit                           0
# Walk                              0
# OtherTransp                       0
# WorkAtHome                        0
# MeanCommute                       0
# MeanHealthCommute                 0
# Employed                          0
# PrivateWork                       0
# PublicWork                        0
# SelfEmployed                      0
# FamilyWork                      281
# Unemployment%_2019                0
# Median Household Income_2019      0
# % of State Median HH Income       0
# dtype: int64

# %%
# Calculating the Missing Values % contribution in DF

df_null = df.isna().mean().round(4) * 100

df_null.sort_values(ascending=False).head()
# Out:
# FamilyWork      48.12
# ChildPoverty     1.54
# StateAbbr        0.00
# Transit          0.00
# IncomePerCap     0.00
# dtype: float64

# %%
# Plotting missing values

sns.heatmap(df.isnull(), cbar=False)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Describe Child Poverty to use in deciding how to impute

# %%
df['ChildPoverty'].describe()
# Out:
# count    575.000000
# mean      26.380522
# std       10.262801
# min        0.000000
# 25%       19.650000
# 50%       26.200000
# 75%       32.000000
# max       63.500000
# Name: ChildPoverty, dtype: float64

# %%
df['ChildPoverty'].median()
# Out:
# 26.2

# %%
df['ChildPoverty'].mode()
# Out:
# 0    14.6
# 1    17.9
# 2    22.6
# 3    24.6
# 4    29.2
# 5    30.6
# Name: ChildPoverty, dtype: float64

# %%
# Fill missing values of ChildPoverty with the average of ChildPoverty (mean)

df[ 'ChildPoverty' ] = df.ChildPoverty.fillna( df.ChildPoverty.mean() )
df_null = df.isna().mean().round(4) * 100

df_null.sort_values(ascending=False).head()
# Out:
# FamilyWork         48.12
# StateAbbr           0.00
# Transit             0.00
# IncomePerCap        0.00
# IncomePerCapErr     0.00
# dtype: float64

# %% [markdown]
# ### Looking for duplicates

# %%
# checking for duplicates

df.loc[df.duplicated()]
# Out:
#     StateAbbr  State    County  CountyFIPS  ARTHRITIS  CASTHMA  BPHIGH  \
# 330        TX  Texas  Anderson       48001       25.5      9.3    38.3
#
#      CANCER  HIGHCHOL  KIDNEY  ...  MeanCommute  MeanHealthCommute  Employed  \
# 330     6.4      36.0     3.4  ...         23.7              41.63     19102
#
#      PrivateWork  PublicWork  SelfEmployed  FamilyWork  Unemployment%_2019  \
# 330         73.2        20.4           6.2         NaN                 2.9
#
#     Median Household Income_2019  % of State Median HH Income
# 330                        48461                     0.756683
#
# [1 rows x 53 columns]

# %%
# This will drop all duplicate rows

df.drop_duplicates(keep = 'first', inplace = True) 

# keep - which duplicate to keep, default is none!

# %%
df.loc[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [StateAbbr, State, County, CountyFIPS, ARTHRITIS, CASTHMA, BPHIGH, CANCER, HIGHCHOL, KIDNEY, COPD, CHD, DIABETES, MHLTH, PHLTH, TEETHLOST, STROKE, TotalPopulation, GenderMajority, Men, Women, Hispanic, White, Black, Native, Asian, Pacific, VotingAgeCitizen, Income, IncomePerCap, IncomePerCapErr, ChildPoverty, Professional, Service, Office, Construction, Production, Drive, Carpool, Transit, Walk, OtherTransp, WorkAtHome, MeanCommute, MeanHealthCommute, Employed, PrivateWork, PublicWork, SelfEmployed, FamilyWork, Unemployment%_2019, Median Household Income_2019, % of State Median HH Income]
# Index: []
#
# [0 rows x 53 columns]

# %%
df.shape
# Out:
# (583, 53)

# %% [markdown]
# ### Changing the data type

# %%
# changing the datatype of countyFIPS.  It is being treated as a number but it is really a string.

df['CountyFIPS'] = df['CountyFIPS'].astype(str)

# %% [markdown]
# ### Remove a single column

# %% [markdown]
# The FamilyWork column will be removed because it contains too many null values.

# %%
df = df.drop('FamilyWork',axis=1)

# %% [markdown]
# ### Remove multiple columns

# %%
drop_columns = {'VotingAgeCitizen','Income','IncomePerCapErr','IncomePerCap' }
df = df.drop(columns = drop_columns) # inplace=True not used so columns still exist. Just not in this instance.

# %%
df.shape
# Out:
# (583, 48)

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ## Examine Diabetes column

# %%
# Mean Diabetes value by State

plt.figure(figsize=(20,20))

dfx = pd.DataFrame(df.groupby(['StateAbbr'])['DIABETES'].mean().sort_values(ascending = False))
dfx.plot.bar()
plt.title('Mean Diabetes Value for States')
plt.show()

# %%
# Basic statistics for DIABETES

df['DIABETES'].describe()
# Out:
# count    583.000000
# mean      14.674786
# std        2.458319
# min        6.700000
# 25%       13.200000
# 50%       14.600000
# 75%       16.000000
# max       23.900000
# Name: DIABETES, dtype: float64

# %% [markdown]
# ### Histograms

# %%
# Plot a histogram of DIABETES
plt.figure(figsize=(30,10))
sns.histplot(df['DIABETES'], kde = False).set_title('Histogram of Diabetes')
#plt.show()
plt.savefig('xyz.png')

# %%
# Basic Distribution (Histogram) plot

plt.figure(figsize=(10,10))
plt.title('Diabetes Distribution Plot')
sns.histplot(df['DIABETES'],bins=50,kde=False)   # This allows control over the number of bins
# Out:
# <AxesSubplot:title={'center':'Diabetes Distribution Plot'}, xlabel='DIABETES', ylabel='Count'>

# %% [markdown]
# ### Boxplots

# %%
# Basic boxplot

sns.boxplot(y="DIABETES", data=df,palette='rainbow')
# sns.boxplot(y="DIABETES", data=df,palette='rainbow',orient='h')  change the orientation
# Out:
# <AxesSubplot:ylabel='DIABETES'>

# %%
sns.boxplot(data=df['DIABETES'], orient="v", palette='Set3' ,whis=1.5,saturation=1, width=0.7)
plt.title("Diabetes Boxplot", fontsize = 14, fontweight = 'bold')
plt.ylabel("Diabetes Range", fontweight = 'bold')
plt.xlabel("Continuous Variable", fontweight = 'bold')
# Out:
# Text(0.5, 0, 'Continuous Variable')

# %%
# Boxplot stratified by carbody

sns.boxplot(x='GenderMajority', y='DIABETES', data=df,palette='rainbow')
# Out:
# <AxesSubplot:xlabel='GenderMajority', ylabel='DIABETES'>

# %%
# Multiple boxplots
plt.figure(figsize=(20, 15))
plt.subplot(3,3,1)
sns.boxplot(y = 'CASTHMA', x = 'State', data = df)
plt.subplot(3,3,2)
sns.boxplot(y = 'BPHIGH', x = 'State', data = df)
plt.subplot(3,3,3)
sns.boxplot(y = 'CANCER', x = 'State', data = df)
plt.subplot(3,3,4)
sns.boxplot(y = 'HIGHCHOL', x = 'State', data = df)
plt.subplot(3,3,5)
sns.boxplot(y = 'KIDNEY', x = 'State', data = df)
plt.subplot(3,3,6)
sns.boxplot(y = 'COPD', x = 'State', data = df)
plt.subplot(3,3,7)
sns.boxplot(y = 'CHD', x = 'State', data = df)
plt.subplot(3,3,8)
sns.boxplot(y = 'MHLTH', x = 'State', data = df)
plt.subplot(3,3,9)
sns.boxplot(x = 'PHLTH', y = 'State', data = df)
plt.show()

# %% [markdown]
# ### Violinplots

# %%
# Violinplot stratified by carbody

sns.violinplot(y='DIABETES', data=df,palette='rainbow')
# Out:
# <AxesSubplot:ylabel='DIABETES'>

# %% [markdown]
# ### Counting unique values for each variable

# %%
for column in df.columns:
    print(f"{column}: Number of unique values {df[column].nunique()}")
    print("==========================================================")
# Out:
# StateAbbr: Number of unique values 4
# ==========================================================
# State: Number of unique values 4
# ==========================================================
# County: Number of unique values 473
# ==========================================================
# CountyFIPS: Number of unique values 583
# ==========================================================
# ARTHRITIS: Number of unique values 204
# ==========================================================
# CASTHMA: Number of unique values 43
# ==========================================================
# BPHIGH: Number of unique values 188
# ==========================================================
# CANCER: Number of unique values 59
# ==========================================================
# HIGHCHOL: Number of unique values 136
# ==========================================================
# KIDNEY: Number of unique values 35
# ==========================================================
# COPD: Number of unique values 96
# ==========================================================
# CHD: Number of unique values 83
# ==========================================================
# DIABETES: Number of unique values 114
# ==========================================================
# MHLTH: Number of unique values 83
# ==========================================================
# PHLTH: Number of unique values 117
# ==========================================================
# TEETHLOST: Number of unique values 174
# ==========================================================
# STROKE: Number of unique values 48
# ==========================================================
# TotalPopulation: Number of unique values 582
# ==========================================================
# GenderMajority: Number of unique values 2
# ==========================================================
# Men: Number of unique values 577
# ==========================================================
# Women: Number of unique values 581
# ==========================================================
# Hispanic: Number of unique values 295
# ==========================================================
# White: Number of unique values 395
# ==========================================================
# Black: Number of unique values 276
# ==========================================================
# Native: Number of unique values 22
# ==========================================================
# Asian: Number of unique values 56
# ==========================================================
# Pacific: Number of unique values 12
# ==========================================================
# ChildPoverty: Number of unique values 298
# ==========================================================
# Professional: Number of unique values 200
# ==========================================================
# Service: Number of unique values 163
# ==========================================================
# Office: Number of unique values 143
# ==========================================================
# Construction: Number of unique values 175
# ==========================================================
# Production: Number of unique values 210
# ==========================================================
# Drive: Number of unique values 179
# ==========================================================
# Carpool: Number of unique values 154
# ==========================================================
# Transit: Number of unique values 29
# ==========================================================
# Walk: Number of unique values 66
# ==========================================================
# OtherTransp: Number of unique values 56
# ==========================================================
# WorkAtHome: Number of unique values 97
# ==========================================================
# MeanCommute: Number of unique values 202
# ==========================================================
# MeanHealthCommute: Number of unique values 548
# ==========================================================
# Employed: Number of unique values 574
# ==========================================================
# PrivateWork: Number of unique values 209
# ==========================================================
# PublicWork: Number of unique values 185
# ==========================================================
# SelfEmployed: Number of unique values 131
# ==========================================================
# Unemployment%_2019: Number of unique values 54
# ==========================================================
# Median Household Income_2019: Number of unique values 579
# ==========================================================
# % of State Median HH Income: Number of unique values 583
# ==========================================================

# %%
# Looping through all the 'object type' variables and counting how many rows for each unique variable.
object_col = []
for column in df.columns:
    if df[column].dtype == object and len(df[column].unique()) <= 30:
        object_col.append(column)
        print(f"{column} : {df[column].unique()}")
        print(df[column].value_counts())
        print("====================================")
# Out:
# StateAbbr : ['AR' 'GA' 'TN' 'TX']
# TX    254
# GA    159
# TN     95
# AR     75
# Name: StateAbbr, dtype: int64
# ====================================
# State : ['Arkansas' 'Georgia' 'Tennessee' 'Texas']
# Texas        254
# Georgia      159
# Tennessee     95
# Arkansas      75
# Name: State, dtype: int64
# ====================================
# GenderMajority : ['F' 'M']
# F    394
# M    189
# Name: GenderMajority, dtype: int64
# ====================================

# %% [markdown]
# #

# %% [markdown]
# ## Bar Charts

# %%
# Visualizing the number of counties for each State

plt.rcParams['figure.figsize'] = [15,8]
ax=df['State'].value_counts().plot(kind='bar',stacked=True, colormap = 'Set1')
ax.title.set_text('State')
plt.xlabel("Names of the State",fontweight = 'bold')
plt.ylabel("Count of Counties",fontweight = 'bold')
# Out:
# Text(0, 0.5, 'Count of Counties')

# %% [markdown]
# ### Count number of rows for each unique value of a variable

# %%
x= df['State'].value_counts()
x
# Out:
# Texas        254
# Georgia      159
# Tennessee     95
# Arkansas      75
# Name: State, dtype: int64

# %% [markdown]
# ### Multiple bar charts in a figure

# %%
plt.figure(figsize=(25, 6))

plt.subplot(1,3,1)
plt1 = df['State'].value_counts().plot(kind='bar')
plt.title('States')
plt1.set(xlabel = 'State', ylabel='Frequency')

plt.subplot(1,3,2)
plt1 = df['StateAbbr'].value_counts().plot(kind='bar')
plt.title('State Abbreviation')
plt1.set(xlabel = 'State Abbreviation', ylabel='Frequency')

plt.subplot(1,3,3)
plt1 = df['GenderMajority'].value_counts().plot(kind='bar')
plt.title('Gender Majority')
plt1.set(xlabel = 'Gender', ylabel='Frequency of Car Body')
# Out:
# [Text(0.5, 0, 'Gender'), Text(0, 0.5, 'Frequency of Car Body')]

# %% [markdown]
# ### Binning numeric values into groups

# %%
pop_category = pd.cut(df.TotalPopulation,bins=[0,25000,100000,150000,1000000],labels=['Small','Medium','Large','Metro'])
df.insert(4,'Pop Group',pop_category)

# %%
df['Pop Group'].value_counts(normalize=False) # True shows percent of total
# Out:
# Small     325
# Medium    174
# Metro      50
# Large      28
# Name: Pop Group, dtype: int64

# %%
plt.figure(figsize=(15,8))
#plt.rcParams['figure.figsize'] = [15,8]
ax=df['Pop Group'].value_counts().plot(kind='bar',stacked=True, colormap = 'Set1')
ax.title.set_text('Categories')
plt.xlabel("Population Groups",fontweight = 'bold')
plt.ylabel("Count of Rows",fontweight = 'bold')
# Out:
# Text(0, 0.5, 'Count of Rows')

# %% [markdown]
# # Scatterplots

# %%
# Basic scatterplot

plt.scatter(y = df['DIABETES'], x = df['KIDNEY'])
plt.xlabel("KIDNEY",fontweight = 'bold')
plt.ylabel("DIABETES",fontweight = 'bold')
#plt.show()
# Out:
# Text(0, 0.5, 'DIABETES')

# %%
# Multiple plots (Multiple variables vs one variable)

col = ['BPHIGH','HIGHCHOL','MHLTH','PHLTH','STROKE']

# Scatter Plot of independent variables vs dependent variables

fig,axes = plt.subplots(2,3,figsize=(18,15))
for seg,col in enumerate(col):
    x,y = seg//3,seg%3
    an=sns.scatterplot(x=col, y='DIABETES' ,data=df, ax=axes[x,y])
    plt.setp(an.get_xticklabels(), rotation=45)
   
plt.subplots_adjust(hspace=0.5)

# %%
# Pairplot 
#sns.pairplot(df) # This will take a long time to run and return an unreadable image because we have so many columns.

# %%
# Create a new dataframe

df2 = df[['TotalPopulation','ChildPoverty','MeanCommute','MeanHealthCommute','Unemployment%_2019','Median Household Income_2019',]]

# %%
plt.figure(figsize=(8,8))
sns.pairplot(df2)

# %%
xyz = df.corr()
xyz
# Out:
#                               ARTHRITIS   CASTHMA    BPHIGH    CANCER  \
# ARTHRITIS                      1.000000  0.715229  0.859506  0.824879
# CASTHMA                        0.715229  1.000000  0.652535  0.302190
# BPHIGH                         0.859506  0.652535  1.000000  0.706346
# CANCER                         0.824879  0.302190  0.706346  1.000000
# HIGHCHOL                       0.819326  0.349772  0.826335  0.841880
# KIDNEY                         0.605317  0.460599  0.820476  0.495120
# COPD                           0.923124  0.807514  0.826359  0.672753
# CHD                            0.845778  0.503038  0.895697  0.773274
# DIABETES                       0.507431  0.465070  0.769393  0.321906
# MHLTH                          0.561872  0.853209  0.468919  0.060114
# PHLTH                          0.801467  0.751723  0.835455  0.456288
# TEETHLOST                      0.603403  0.792774  0.686041  0.182836
# STROKE                         0.746435  0.674136  0.900113  0.574627
# TotalPopulation               -0.310784 -0.179564 -0.303396 -0.296112
# Men                           -0.311036 -0.181036 -0.303496 -0.296338
# Women                         -0.310490 -0.178101 -0.303250 -0.295845
# Hispanic                      -0.583383 -0.639090 -0.360653 -0.493226
# White                          0.581603  0.292358  0.194493  0.648743
# Black                          0.042813  0.491331  0.277112 -0.174148
# Native                         0.038674 -0.044148 -0.020404  0.071189
# Asian                         -0.396941 -0.253429 -0.415421 -0.345980
# Pacific                       -0.090601 -0.046837 -0.101282 -0.086179
# ChildPoverty                   0.317697  0.549694  0.483488  0.020151
# Professional                  -0.343756 -0.369471 -0.453677 -0.114534
# Service                        0.041365  0.078765  0.206818 -0.043526
# Office                        -0.089547 -0.025637 -0.183403 -0.044481
# Construction                  -0.011685 -0.203655  0.103540  0.088026
# Production                     0.395641  0.515151  0.353355  0.106511
# Drive                          0.162076  0.231704  0.078911  0.049881
# Carpool                       -0.043402 -0.056420  0.033252 -0.037813
# Transit                       -0.272154 -0.055354 -0.236631 -0.281782
# Walk                          -0.103875 -0.164078 -0.029068 -0.009061
# OtherTransp                   -0.024202  0.033627  0.031378 -0.044638
# WorkAtHome                    -0.111759 -0.285861 -0.150904  0.063083
# MeanCommute                    0.133394  0.129383  0.033310  0.116649
# MeanHealthCommute             -0.044955 -0.086470 -0.204719  0.022716
# Employed                      -0.310079 -0.182201 -0.305078 -0.290115
# PrivateWork                   -0.083151  0.061003 -0.250235 -0.141199
# PublicWork                    -0.020347  0.057267  0.150760 -0.088139
# SelfEmployed                   0.195960 -0.208759  0.234025  0.416751
# Unemployment%_2019             0.334883  0.450337  0.449852  0.068699
# Median Household Income_2019  -0.498686 -0.564177 -0.622247 -0.224692
# % of State Median HH Income   -0.306499 -0.397797 -0.499670 -0.131180
#
#                               HIGHCHOL    KIDNEY      COPD       CHD  \
# ARTHRITIS                     0.819326  0.605317  0.923124  0.845778
# CASTHMA                       0.349772  0.460599  0.807514  0.503038
# BPHIGH                        0.826335  0.820476  0.826359  0.895697
# CANCER                        0.841880  0.495120  0.672753  0.773274
# HIGHCHOL                      1.000000  0.685090  0.754244  0.910222
# KIDNEY                        0.685090  1.000000  0.688910  0.870916
# COPD                          0.754244  0.688910  1.000000  0.854454
# CHD                           0.910222  0.870916  0.854454  1.000000
# DIABETES                      0.576837  0.966569  0.614523  0.768358
# MHLTH                         0.293251  0.363286  0.732516  0.437845
# PHLTH                         0.706814  0.807830  0.899515  0.862027
# TEETHLOST                     0.402515  0.703390  0.785209  0.656074
# STROKE                        0.675116  0.936904  0.828445  0.877020
# TotalPopulation              -0.303217 -0.274550 -0.323924 -0.347214
# Men                          -0.301959 -0.274271 -0.323465 -0.346132
# Women                        -0.304395 -0.274778 -0.324320 -0.348215
# Hispanic                     -0.172996  0.006451 -0.533189 -0.208479
# White                         0.408892 -0.165587  0.478313  0.272064
# Black                        -0.265200  0.276967  0.119763 -0.027937
# Native                        0.060311 -0.100165  0.014524  0.041602
# Asian                        -0.445488 -0.395552 -0.421347 -0.466787
# Pacific                      -0.116265 -0.120693 -0.095444 -0.106191
# ChildPoverty                  0.211878  0.641565  0.478245  0.443357
# Professional                 -0.386433 -0.549848 -0.496269 -0.506283
# Service                       0.122320  0.392230  0.110307  0.248885
# Office                       -0.213238 -0.256233 -0.171350 -0.254619
# Construction                  0.278588  0.282594  0.072362  0.277011
# Production                    0.217611  0.217545  0.486337  0.278693
# Drive                         0.037423 -0.096078  0.145744 -0.025140
# Carpool                       0.034869  0.171555  0.001825  0.097605
# Transit                      -0.355478 -0.177025 -0.250451 -0.301443
# Walk                          0.025974  0.094247 -0.099637  0.073196
# OtherTransp                  -0.037441  0.096238  0.012620  0.034830
# WorkAtHome                   -0.036606 -0.139083 -0.176658 -0.089958
# MeanCommute                   0.044751 -0.113993  0.128164 -0.045869
# MeanHealthCommute            -0.131474 -0.411013 -0.133542 -0.298695
# Employed                     -0.301013 -0.279925 -0.324306 -0.348217
# PrivateWork                  -0.244283 -0.353807 -0.117458 -0.311404
# PublicWork                   -0.009123  0.273732  0.051788  0.131646
# SelfEmployed                  0.484795  0.230418  0.142132  0.380981
# Unemployment%_2019            0.241172  0.506352  0.419453  0.402003
# Median Household Income_2019 -0.432217 -0.728588 -0.637376 -0.662710
# % of State Median HH Income  -0.356321 -0.727314 -0.501332 -0.574963
#
#                               DIABETES     MHLTH  ...  WorkAtHome  \
# ARTHRITIS                     0.507431  0.561872  ...   -0.111759
# CASTHMA                       0.465070  0.853209  ...   -0.285861
# BPHIGH                        0.769393  0.468919  ...   -0.150904
# CANCER                        0.321906  0.060114  ...    0.063083
# HIGHCHOL                      0.576837  0.293251  ...   -0.036606
# KIDNEY                        0.966569  0.363286  ...   -0.139083
# COPD                          0.614523  0.732516  ...   -0.176658
# CHD                           0.768358  0.437845  ...   -0.089958
# DIABETES                      1.000000  0.397129  ...   -0.182815
# MHLTH                         0.397129  1.000000  ...   -0.315215
# PHLTH                         0.789647  0.787895  ...   -0.246849
# TEETHLOST                     0.721133  0.833341  ...   -0.306160
# STROKE                        0.892425  0.495569  ...   -0.182714
# TotalPopulation              -0.231223 -0.203193  ...    0.089077
# Men                          -0.230994 -0.202734  ...    0.088519
# Women                        -0.231411 -0.203608  ...    0.089607
# Hispanic                      0.100133 -0.331140  ...    0.029412
# White                        -0.327620  0.216683  ...    0.075289
# Black                         0.367135  0.184448  ...   -0.168846
# Native                       -0.140463  0.020377  ...    0.006015
# Asian                        -0.351003 -0.326765  ...    0.173351
# Pacific                      -0.113756 -0.030086  ...    0.001896
# ChildPoverty                  0.675900  0.541126  ...   -0.217006
# Professional                 -0.588040 -0.516198  ...    0.275007
# Service                       0.414419  0.155844  ...   -0.010013
# Office                       -0.257619 -0.147270  ...    0.073507
# Construction                  0.259011 -0.041254  ...   -0.058269
# Production                    0.261778  0.553500  ...   -0.278211
# Drive                        -0.073612  0.203392  ...   -0.478917
# Carpool                       0.178415 -0.011972  ...   -0.112634
# Transit                      -0.144428 -0.128070  ...    0.102865
# Walk                          0.055861 -0.095541  ...    0.184261
# OtherTransp                   0.103370  0.010806  ...    0.097831
# WorkAtHome                   -0.182815 -0.315215  ...    1.000000
# MeanCommute                  -0.102469  0.029536  ...    0.124799
# MeanHealthCommute            -0.402932 -0.197284  ...    0.218046
# Employed                     -0.239664 -0.210728  ...    0.096846
# PrivateWork                  -0.330251  0.016116  ...   -0.153476
# PublicWork                    0.301048  0.086159  ...   -0.022572
# SelfEmployed                  0.141612 -0.172614  ...    0.331124
# Unemployment%_2019            0.543784  0.460117  ...   -0.163510
# Median Household Income_2019 -0.721962 -0.632463  ...    0.274785
# % of State Median HH Income  -0.732308 -0.472498  ...    0.244687
#
#                               MeanCommute  MeanHealthCommute  Employed  \
# ARTHRITIS                        0.133394          -0.044955 -0.310079
# CASTHMA                          0.129383          -0.086470 -0.182201
# BPHIGH                           0.033310          -0.204719 -0.305078
# CANCER                           0.116649           0.022716 -0.290115
# HIGHCHOL                         0.044751          -0.131474 -0.301013
# KIDNEY                          -0.113993          -0.411013 -0.279925
# COPD                             0.128164          -0.133542 -0.324306
# CHD                             -0.045869          -0.298695 -0.348217
# DIABETES                        -0.102469          -0.402932 -0.239664
# MHLTH                            0.029536          -0.197284 -0.210728
# PHLTH                           -0.026721          -0.309731 -0.305114
# TEETHLOST                       -0.059173          -0.351177 -0.267286
# STROKE                          -0.011839          -0.311918 -0.298828
# TotalPopulation                  0.091455           0.179421  0.998327
# Men                              0.090888           0.178324  0.998322
# Women                            0.091993           0.180462  0.998174
# Hispanic                        -0.334143          -0.297500  0.100009
# White                            0.284939           0.319702 -0.185503
# Black                            0.051979          -0.067951  0.056907
# Native                          -0.027368           0.002112 -0.037337
# Asian                            0.085686           0.275345  0.524260
# Pacific                         -0.036631          -0.023955  0.019167
# ChildPoverty                    -0.107604          -0.362574 -0.095635
# Professional                     0.047375           0.335958  0.316247
# Service                         -0.177875          -0.336317 -0.050234
# Office                           0.090889           0.200423  0.169814
# Construction                    -0.110212          -0.231302 -0.233502
# Production                       0.115188          -0.040840 -0.206066
# Drive                            0.089638           0.101583 -0.050003
# Carpool                         -0.047732          -0.127813 -0.057133
# Transit                          0.078016           0.115605  0.466215
# Walk                            -0.321023          -0.306951 -0.063154
# OtherTransp                     -0.046993          -0.068469  0.035318
# WorkAtHome                       0.124799           0.218046  0.096846
# MeanCommute                      1.000000           0.898029  0.095380
# MeanHealthCommute                0.898029           1.000000  0.187461
# Employed                         0.095380           0.187461  1.000000
# PrivateWork                      0.169649           0.294432  0.241639
# PublicWork                      -0.153540          -0.279656 -0.201156
# SelfEmployed                    -0.062658          -0.095386 -0.130197
# Unemployment%_2019               0.060469          -0.158966 -0.078353
# Median Household Income_2019     0.237852           0.609456  0.263592
# % of State Median HH Income      0.253197           0.644495  0.242249
#
#                               PrivateWork  PublicWork  SelfEmployed  \
# ARTHRITIS                       -0.083151   -0.020347      0.195960
# CASTHMA                          0.061003    0.057267     -0.208759
# BPHIGH                          -0.250235    0.150760      0.234025
# CANCER                          -0.141199   -0.088139      0.416751
# HIGHCHOL                        -0.244283   -0.009123      0.484795
# KIDNEY                          -0.353807    0.273732      0.230418
# COPD                            -0.117458    0.051788      0.142132
# CHD                             -0.311404    0.131646      0.380981
# DIABETES                        -0.330251    0.301048      0.141612
# MHLTH                            0.016116    0.086159     -0.172614
# PHLTH                           -0.188075    0.152656      0.111291
# TEETHLOST                       -0.158147    0.239792     -0.089953
# STROKE                          -0.275069    0.239817      0.134991
# TotalPopulation                  0.240073   -0.197025     -0.134056
# Men                              0.237845   -0.195015     -0.133126
# Women                            0.242208   -0.198954     -0.134942
# Hispanic                        -0.148595    0.084550      0.144780
# White                            0.137878   -0.264211      0.169146
# Black                           -0.013184    0.264472     -0.407101
# Native                          -0.090227    0.029428      0.129449
# Asian                            0.256764   -0.170851     -0.209620
# Pacific                         -0.005487    0.039896     -0.056768
# ChildPoverty                    -0.097847    0.198722     -0.136022
# Professional                     0.072734   -0.055963     -0.043531
# Service                         -0.316352    0.349564      0.025420
# Office                           0.356580   -0.298879     -0.194599
# Construction                    -0.246384    0.095376      0.312541
# Production                       0.142051   -0.094428     -0.112716
# Drive                            0.266609   -0.122032     -0.307398
# Carpool                         -0.092588    0.042305      0.103318
# Transit                          0.155924   -0.064097     -0.190058
# Walk                            -0.372789    0.261825      0.279045
# OtherTransp                     -0.071926    0.077458      0.018339
# WorkAtHome                      -0.153476   -0.022572      0.331124
# MeanCommute                      0.169649   -0.153540     -0.062658
# MeanHealthCommute                0.294432   -0.279656     -0.095386
# Employed                         0.241639   -0.201156     -0.130197
# PrivateWork                      1.000000   -0.855864     -0.506911
# PublicWork                      -0.855864    1.000000     -0.009053
# SelfEmployed                    -0.506911   -0.009053      1.000000
# Unemployment%_2019              -0.117374    0.228101     -0.151917
# Median Household Income_2019     0.312303   -0.329183     -0.055411
# % of State Median HH Income      0.367115   -0.366116     -0.098908
#
#                               Unemployment%_2019  \
# ARTHRITIS                               0.334883
# CASTHMA                                 0.450337
# BPHIGH                                  0.449852
# CANCER                                  0.068699
# HIGHCHOL                                0.241172
# KIDNEY                                  0.506352
# COPD                                    0.419453
# CHD                                     0.402003
# DIABETES                                0.543784
# MHLTH                                   0.460117
# PHLTH                                   0.551243
# TEETHLOST                               0.564419
# STROKE                                  0.512155
# TotalPopulation                        -0.066862
# Men                                    -0.066613
# Women                                  -0.067094
# Hispanic                               -0.077467
# White                                  -0.143752
# Black                                   0.325100
# Native                                 -0.129945
# Asian                                  -0.143454
# Pacific                                -0.077422
# ChildPoverty                            0.552996
# Professional                           -0.361612
# Service                                 0.358382
# Office                                 -0.148704
# Construction                           -0.033581
# Production                              0.238845
# Drive                                   0.050161
# Carpool                                 0.003638
# Transit                                -0.011384
# Walk                                    0.003231
# OtherTransp                             0.102999
# WorkAtHome                             -0.163510
# MeanCommute                             0.060469
# MeanHealthCommute                      -0.158966
# Employed                               -0.078353
# PrivateWork                            -0.117374
# PublicWork                              0.228101
# SelfEmployed                           -0.151917
# Unemployment%_2019                      1.000000
# Median Household Income_2019           -0.532665
# % of State Median HH Income            -0.476967
#
#                               Median Household Income_2019  \
# ARTHRITIS                                        -0.498686
# CASTHMA                                          -0.564177
# BPHIGH                                           -0.622247
# CANCER                                           -0.224692
# HIGHCHOL                                         -0.432217
# KIDNEY                                           -0.728588
# COPD                                             -0.637376
# CHD                                              -0.662710
# DIABETES                                         -0.721962
# MHLTH                                            -0.632463
# PHLTH                                            -0.777069
# TEETHLOST                                        -0.797661
# STROKE                                           -0.727556
# TotalPopulation                                   0.252685
# Men                                               0.251761
# Women                                             0.253546
# Hispanic                                          0.049747
# White                                             0.102402
# Black                                            -0.259296
# Native                                            0.020417
# Asian                                             0.446999
# Pacific                                           0.004651
# ChildPoverty                                     -0.668175
# Professional                                      0.650665
# Service                                          -0.436595
# Office                                            0.258061
# Construction                                     -0.216929
# Production                                       -0.347130
# Drive                                             0.038413
# Carpool                                          -0.181133
# Transit                                           0.124372
# Walk                                             -0.091539
# OtherTransp                                      -0.064434
# WorkAtHome                                        0.274785
# MeanCommute                                       0.237852
# MeanHealthCommute                                 0.609456
# Employed                                          0.263592
# PrivateWork                                       0.312303
# PublicWork                                       -0.329183
# SelfEmployed                                     -0.055411
# Unemployment%_2019                               -0.532665
# Median Household Income_2019                      1.000000
# % of State Median HH Income                       0.936785
#
#                               % of State Median HH Income
# ARTHRITIS                                       -0.306499
# CASTHMA                                         -0.397797
# BPHIGH                                          -0.499670
# CANCER                                          -0.131180
# HIGHCHOL                                        -0.356321
# KIDNEY                                          -0.727314
# COPD                                            -0.501332
# CHD                                             -0.574963
# DIABETES                                        -0.732308
# MHLTH                                           -0.472498
# PHLTH                                           -0.633039
# TEETHLOST                                       -0.670039
# STROKE                                          -0.671580
# TotalPopulation                                  0.231181
# Men                                              0.229797
# Women                                            0.232494
# Hispanic                                        -0.104522
# White                                            0.247294
# Black                                           -0.249056
# Native                                           0.073003
# Asian                                            0.423355
# Pacific                                          0.014354
# ChildPoverty                                    -0.632050
# Professional                                     0.647358
# Service                                         -0.467488
# Office                                           0.268583
# Construction                                    -0.309033
# Production                                      -0.251979
# Drive                                            0.092820
# Carpool                                         -0.208435
# Transit                                          0.106891
# Walk                                            -0.129561
# OtherTransp                                     -0.083724
# WorkAtHome                                       0.244687
# MeanCommute                                      0.253197
# MeanHealthCommute                                0.644495
# Employed                                         0.242249
# PrivateWork                                      0.367115
# PublicWork                                      -0.366116
# SelfEmployed                                    -0.098908
# Unemployment%_2019                              -0.476967
# Median Household Income_2019                     0.936785
# % of State Median HH Income                      1.000000
#
# [43 rows x 43 columns]

# %%
sns.heatmap(xyz, annot=False)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(15,15))
corr = df.corr()
ax = sns.heatmap(
    corr,
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(20, 220, n=200),
    square=True,
    annot=True, annot_kws={"size":10}
)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=45,
    horizontalalignment='right'
);

# %%
plt.figure(figsize=(20, 20))
corr = df.corr()
ax = sns.heatmap(
    corr,
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(20, 220, n=200),
    square=True,
    annot=False, annot_kws={"size":20}
)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=45,
    horizontalalignment='right'
);

# %% [markdown]
# # Linear regressions

# %%
# Run price vs. citympg

model = sm.OLS.from_formula('DIABETES ~ COPD', data=df)
result = model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               DIABETES   R-squared:                       0.378
# Model:                            OLS   Adj. R-squared:                  0.377
# Method:                 Least Squares   F-statistic:                     352.5
# Date:                Wed, 05 Apr 2023   Prob (F-statistic):           7.93e-62
# Time:                        11:21:43   Log-Likelihood:                -1212.9
# No. Observations:                 583   AIC:                             2430.
# Df Residuals:                     581   BIC:                             2439.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      7.8728      0.371     21.216      0.000       7.144       8.602
# COPD           0.7076      0.038     18.776      0.000       0.634       0.782
# ==============================================================================
# Omnibus:                      109.192   Durbin-Watson:                   1.560
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              191.621
# Skew:                           1.113   Prob(JB):                     2.46e-42
# Kurtosis:                       4.712   Cond. No.                         45.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
# Run a different variable against DIABETES

#... code here ......
result = model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               DIABETES   R-squared:                       0.378
# Model:                            OLS   Adj. R-squared:                  0.377
# Method:                 Least Squares   F-statistic:                     352.5
# Date:                Wed, 05 Apr 2023   Prob (F-statistic):           7.93e-62
# Time:                        11:21:43   Log-Likelihood:                -1212.9
# No. Observations:                 583   AIC:                             2430.
# Df Residuals:                     581   BIC:                             2439.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      7.8728      0.371     21.216      0.000       7.144       8.602
# COPD           0.7076      0.038     18.776      0.000       0.634       0.782
# ==============================================================================
# Omnibus:                      109.192   Durbin-Watson:                   1.560
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              191.621
# Skew:                           1.113   Prob(JB):                     2.46e-42
# Kurtosis:                       4.712   Cond. No.                         45.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
# Run each of the combinations og IVs (e.g., carheight and curbweight)
# syntax    model = sm.OLS.from_formula('DV ~ IV1+IV2', data=dataframe_name)


#... code here ......
result = model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               DIABETES   R-squared:                       0.378
# Model:                            OLS   Adj. R-squared:                  0.377
# Method:                 Least Squares   F-statistic:                     352.5
# Date:                Wed, 05 Apr 2023   Prob (F-statistic):           7.93e-62
# Time:                        11:21:43   Log-Likelihood:                -1212.9
# No. Observations:                 583   AIC:                             2430.
# Df Residuals:                     581   BIC:                             2439.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      7.8728      0.371     21.216      0.000       7.144       8.602
# COPD           0.7076      0.038     18.776      0.000       0.634       0.782
# ==============================================================================
# Omnibus:                      109.192   Durbin-Watson:                   1.560
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              191.621
# Skew:                           1.113   Prob(JB):                     2.46e-42
# Kurtosis:                       4.712   Cond. No.                         45.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
model = sm.OLS.from_formula('DIABETES ~ COPD+TEETHLOST', data=df)
result = model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               DIABETES   R-squared:                       0.526
# Model:                            OLS   Adj. R-squared:                  0.524
# Method:                 Least Squares   F-statistic:                     322.0
# Date:                Wed, 05 Apr 2023   Prob (F-statistic):           8.83e-95
# Time:                        11:21:43   Log-Likelihood:                -1133.4
# No. Observations:                 583   AIC:                             2273.
# Df Residuals:                     580   BIC:                             2286.
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      6.3795      0.342     18.626      0.000       5.707       7.052
# COPD           0.1450      0.053      2.728      0.007       0.041       0.249
# TEETHLOST      0.3588      0.027     13.480      0.000       0.307       0.411
# ==============================================================================
# Omnibus:                       67.597   Durbin-Watson:                   1.525
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              110.329
# Skew:                           0.755   Prob(JB):                     1.10e-24
# Kurtosis:                       4.505   Cond. No.                         108.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """
